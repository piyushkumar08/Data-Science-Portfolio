# %%
import pandas as pd
import numpy as np

# %%
bank = pd.read_csv("bank_marketing.csv", index_col=(0))

# %%
bank
# Out:
#       age          job  marital  education default  balance housing loan  \
# 0      41     services  married    unknown      no       88     yes   no
# 1      56   technician  married  secondary      no     1938      no  yes
# 2      30     services   single  secondary      no      245      no  yes
# 3      34   management   single   tertiary      no     1396     yes   no
# 4      29   technician   single  secondary      no      -13     yes   no
# ...   ...          ...      ...        ...     ...      ...     ...  ...
# 5576   48       admin.  married  secondary      no     2235     yes  yes
# 5577   40  blue-collar  married    primary      no     -388     yes   no
# 5578   27      student   single  secondary      no       91      no   no
# 5579   46  blue-collar  married  secondary      no     1568     yes   no
# 5580   39     services  married  secondary      no        0     yes   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# ...

# %%
bank.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# deposit      0
# dtype: int64

# %%
x = bank[bank.duplicated(keep="first")]
x
# Out:
# Empty DataFrame
# Columns: [age, job, marital, education, default, balance, housing, loan, contact, day, month, duration, campaign, pdays, previous, poutcome, deposit]
# Index: []

# %% [markdown]
# ### Average age of the clients those who have subscribed to deposit

# %%
age_df = pd.DataFrame(bank)
age_df = age_df[age_df["deposit"]=="yes"]
age_df
# Out:
#       age          job   marital  education default  balance housing loan  \
# 1      56   technician   married  secondary      no     1938      no  yes
# 5      26   unemployed    single  secondary      no      632      no   no
# 6      59      retired   married    primary      no     2074      no   no
# 8      61      retired   married  secondary      no      569      no   no
# 9      35  blue-collar  divorced  secondary      no      336     yes   no
# ...   ...          ...       ...        ...     ...      ...     ...  ...
# 5570   66      retired   married   tertiary      no     1948      no   no
# 5571   37     services    single  secondary      no      278     yes   no
# 5573   45   technician    single  secondary      no      410     yes   no
# 5574   47     services   married  secondary      no      405      no  yes
# 5579   46  blue-collar   married  secondary      no     1568     yes   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome  \
# ...

# %%
age_df["age"].describe()
# Out:
# count    2622.000000
# mean       41.426773
# std        13.560264
# min        18.000000
# 25%        31.000000
# 50%        38.000000
# 75%        50.000000
# max        93.000000
# Name: age, dtype: float64

# %% [markdown]
# ### Maximum number of contacts performed during the campaign for the clients who have not subscribed to deposit

# %%
ndepo = pd.DataFrame(bank)
ndepo = ndepo[ndepo["deposit"]=="no"]
ndepo
# Out:
#       age          job  marital  education default  balance housing loan  \
# 0      41     services  married    unknown      no       88     yes   no
# 2      30     services   single  secondary      no      245      no  yes
# 3      34   management   single   tertiary      no     1396     yes   no
# 4      29   technician   single  secondary      no      -13     yes   no
# 7      46   management  married   tertiary      no        3      no   no
# ...   ...          ...      ...        ...     ...      ...     ...  ...
# 5575   31   technician  married  secondary      no      589     yes  yes
# 5576   48       admin.  married  secondary      no     2235     yes  yes
# 5577   40  blue-collar  married    primary      no     -388     yes   no
# 5578   27      student   single  secondary      no       91      no   no
# 5580   39     services  married  secondary      no        0     yes   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# ...

# %%
ndepo["campaign"].describe()
# Out:
# count    2959.000000
# mean        2.833728
# std         3.308879
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         3.000000
# max        63.000000
# Name: campaign, dtype: float64

# %% [markdown]
# ### Difference between the maximum balance (in euros) for the clients who have subscribed to deposit and for the clients who have not subscribed to the deposit

# %%
print("[Max Balance of Deposit = yes] : ", age_df["balance"].max())
print("[Max Balance of Deposit = no] : ",ndepo["balance"].max())
age_df["balance"].max()-ndepo["balance"].max()
# Out:
# [Max Balance of Deposit = yes] :  81204
# [Max Balance of Deposit = no] :  56831
# 24373

# %% [markdown]
# ### Unique job levels in the data and No of clients in management level

# %%
bank["job"].describe()
# Out:
# count           5581
# unique            12
# top       management
# freq            1318
# Name: job, dtype: object

# %% [markdown]
# ##### 12 level of jobs and 1318 clients in management level

# %% [markdown]
# ### Scatter plot of “age” vs “balance”

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(bank["age"],bank["balance"], c="blue")
plt.title("SCATTER PLOT: AGE vs BALANCE")
plt.xlabel("Age of client")
plt.ylabel("Balance")
# Out:
# Text(0, 0.5, 'Balance')

# %% [markdown]
# ### Unemployed clients who have subscribed to deposit

# %%
unemp = bank[bank["job"]=="unemployed"]
unemp
# Out:
#       age         job   marital  education default  balance housing loan  \
# 5      26  unemployed    single  secondary      no      632      no   no
# 10     51  unemployed   married  secondary      no     1416      no   no
# 61     50  unemployed   married  secondary      no     3478     yes   no
# 160    46  unemployed   married  secondary      no    16397      no   no
# 243    26  unemployed    single   tertiary      no      814      no   no
# ...   ...         ...       ...        ...     ...      ...     ...  ...
# 5370   37  unemployed    single  secondary      no      381     yes   no
# 5377   31  unemployed   married  secondary      no        6      no   no
# 5422   48  unemployed  divorced  secondary      no      201      no   no
# 5464   25  unemployed    single   tertiary      no      343      no   no
# 5479   37  unemployed   married   tertiary      no     7620      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# ...

# %%
unemp = unemp[unemp["deposit"]=="yes"]
unemp
# Out:
#       age         job   marital  education default  balance housing loan  \
# 5      26  unemployed    single  secondary      no      632      no   no
# 10     51  unemployed   married  secondary      no     1416      no   no
# 243    26  unemployed    single   tertiary      no      814      no   no
# 252    28  unemployed   married    primary      no     7459     yes   no
# 440    56  unemployed   married  secondary      no        0      no   no
# ...   ...         ...       ...        ...     ...      ...     ...  ...
# 5370   37  unemployed    single  secondary      no      381     yes   no
# 5377   31  unemployed   married  secondary      no        6      no   no
# 5422   48  unemployed  divorced  secondary      no      201      no   no
# 5464   25  unemployed    single   tertiary      no      343      no   no
# 5479   37  unemployed   married   tertiary      no     7620      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# ...
